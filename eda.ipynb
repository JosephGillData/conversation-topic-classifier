# %%
import pandas as pd

# %%
# Import conversation data
convo_df = pd.read_csv('./data/conversations.csv')
convo_df.head()
# Out:
#    conversation_id                                       conversation
# 0                1  Agent: Thank you for calling BrownBox Customer...
# 1                2  Agent: Thank you for calling BrownBox customer...
# 2                3  Agent: Thank you for calling BrownBox Customer...
# 3                4  Customer: Hi, I am facing an issue while loggi...
# 4                5  Agent: Thank you for contacting BrownBox custo...

# %%
# Import taxonomoy data
taxo_df = pd.read_csv('./data/taxonomy.csv')
taxo_df.head()
# Out:
#    taxonomy_id                           taxonomy_name  \
# 0            1             Orders, Shipping & Delivery
# 1            2            Returns, Refunds & Exchanges
# 2            3    Product Defects & Fulfillment Errors
# 3            4  Billing, Charges & Price Discrepancies
# 4            5       Account Access & Customer Profile
#
#                               taxonomoy_decscription
# 0  Definition: Customer enquiries related to the ...
# 1  Definition: Requests to return products, excha...
# 2  Definition: Reports that a product is faulty, ...
# 3  Definition: Questions or disputes about paymen...
# 4  Definition: Issues related to customer login, ...

# %%
# Conversation length analysis
max_conversation_len = df["conversation"].apply(len).max()
print(max_conversation_len)

df["conversation_len"] = df["conversation"].apply(len)
df["conversation_len"].describe()
# Out:
# 5708
# count    1000.000000
# mean     2130.763000
# std       573.887935
# min        46.000000
# 25%      1760.750000
# 50%      2059.500000
# 75%      2432.000000
# max      5708.000000
# Name: conversation_len, dtype: float64
